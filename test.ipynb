# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go
import pandas as pd
import numpy as np

# read the case time series data
cases = pd.read_csv("data/case_time_series.csv")
cases['Case_Date'] = pd.to_datetime(cases['Date_YMD'], format='%Y-%m-%d')

# cases.head()

# lets remove the data for last 3 days so we can predict
cases.drop(cases.tail(3).index, inplace = True)

# cases.tail()
# Out:
#            Date    Date_YMD  Daily Confirmed  Total Confirmed  \
# 459  3 May 2021  2021-05-03           355769         20275414
# 460  4 May 2021  2021-05-04           382847         20658261
# 461  5 May 2021  2021-05-05           412624         21070885
# 462  6 May 2021  2021-05-06           414280         21485165
# 463  7 May 2021  2021-05-07           406902         21892067
#
#      Daily Recovered  Total Recovered  Daily Deceased  Total Deceased  \
# 459           318910         16600620            3439          221795
# 460           337699         16938319            3786          225581
# 461           330718         17269037            3979          229560
# 462           328347         17597384            3923          233483
# 463           327675         17925059            4233          237716
#
#      Case_Date
# 459 2021-05-03
# 460 2021-05-04
# 461 2021-05-05
# 462 2021-05-06
# 463 2021-05-07

# %%
tests = pd.read_csv("data/tested_numbers_icmr_data.csv")
tests['Testing_Date'] = pd.to_datetime([i.split(' ', 1)[0] for i in tests['Update Time Stamp']], infer_datetime_format=True)
tests.tail()
# Out:
#        Update Time Stamp Tested As Of  \
# 422  07/05/2021 09:00:00     6/5/2021
# 423  08/05/2021 09:00:00     7/5/2021
# 424  09/05/2021 09:00:00     8/5/2021
# 425  10/05/2021 09:00:00     9/5/2021
# 426  11/05/2021 09:00:00    10/5/2021
#
#      Daily RTPCR Samples Collected_ICMR Application  \
# 422                                       1001025.0
# 423                                        980291.0
# 424                                        934541.0
# 425                                        580038.0
# 426                                       1013002.0
#
#      Total RTPCR Samples Collected_ICMR Application  Total Samples Tested  \
# 422                                     144569326.0           298601699.0
# 423                                     145549617.0           300410043.0
# 424                                     146484158.0           302275471.0
# 425                                     147064196.0           303750077.0
# 426                                     148077198.0           305600187.0
#
#      Total Individuals Tested Total Positive Cases  \
# 422                       NaN                  NaN
# 423                       NaN                  NaN
# 424                       NaN                  NaN
# 425                       NaN                  NaN
# 426                       NaN                  NaN
#
#      Tests conducted by Private Labs Positive cases from samples reported  \
# 422                              NaN                                  NaN
# 423                              NaN                                  NaN
# 424                              NaN                                  NaN
# 425                              NaN                                  NaN
# 426                              NaN                                  NaN
#
#     Sample Reported today  ...  Registration (Above 45 Years)  \
# 422               1826490  ...                    128634493.0
# 423               1808344  ...                    129757035.0
# 424               1865428  ...                    130795455.0
# 425               1474606  ...                    131359680.0
# 426               1850110  ...                    132508810.0
#
#      Total Doses Administered  Total Individuals Vaccinated  \
# 422               164973058.0                   132087824.0
# 423               167346544.0                   133112446.0
# 424               169439663.0                   133980544.0
# 425               170176603.0                   134404867.0
# 426               172710066.0                   135494474.0
#
#      Total Sessions Conducted  Total Individuals Registered  \
# 422                 2411300.0                   184811384.0
# 423                 2437299.0                   187851699.0
# 424                 2454021.0                   191070066.0
# 425                 2470799.0                   193769891.0
# 426                 2515519.0                   197663279.0
#
#                                                 Source  Source 2  Source 3  \
# 422  https://twitter.com/ICMRDELHI/status/139050530...       NaN       NaN
# 423  https://twitter.com/ICMRDELHI/status/139087731...       NaN       NaN
# 424  https://twitter.com/ICMRDELHI/status/139123636...       NaN       NaN
# 425  https://twitter.com/ICMRDELHI/status/139159328...       NaN       NaN
# 426  https://twitter.com/ICMRDELHI/status/139195637...       NaN       NaN
#
#                                               Source 4  Testing_Date
# 422  https://pib.gov.in/PressReleasePage.aspx?PRID=...    2021-05-07
# 423  https://pib.gov.in/PressReleasePage.aspx?PRID=...    2021-05-08
# 424  https://twitter.com/MoHFW_INDIA/status/1391290...    2021-05-09
# 425  https://pib.gov.in/PressReleasePage.aspx?PRID=...    2021-05-10
# 426  https://pib.gov.in/PressReleasePage.aspx?PRID=...    2021-05-11
#
# [5 rows x 37 columns]

# %%
# there are some duplicate rows in tests - drop them
tests.drop_duplicates(subset=['Testing_Date'], inplace=True)
tests.head()
# Out:
#      Update Time Stamp Tested As Of  \
# 0  13/03/2020 00:00:00   13/03/2020
# 1  18/03/2020 18:00:00   18/03/2020
# 2  19/03/2020 10:00:00   19/03/2020
# 4  20/03/2020 10:00:00   20/03/2020
# 6  21/03/2020 10:00:00   21/03/2020
#
#    Daily RTPCR Samples Collected_ICMR Application  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 4                                             NaN
# 6                                             NaN
#
#    Total RTPCR Samples Collected_ICMR Application  Total Samples Tested  \
# 0                                             NaN                6500.0
# 1                                             NaN               13125.0
# 2                                             NaN               13316.0
# 4                                             NaN               14376.0
# 6                                             NaN               15701.0
#
#    Total Individuals Tested Total Positive Cases  \
# 0                    5900.0                   78
# 1                   12235.0                  150
# 2                   12426.0                  168
# 4                   13486.0                  206
# 6                   14811.0                  271
#
#    Tests conducted by Private Labs Positive cases from samples reported  \
# 0                              NaN                                  NaN
# 1                              NaN                                  NaN
# 2                              NaN                                  NaN
# 4                              NaN                                  NaN
# 6                              NaN                                  NaN
#
#   Sample Reported today  ...  Registration (Above 45 Years)  \
# 0                   NaN  ...                            NaN
# 1                   NaN  ...                            NaN
# 2                   NaN  ...                            NaN
# 4                   NaN  ...                            NaN
# 6                   NaN  ...                            NaN
#
#    Total Doses Administered  Total Individuals Vaccinated  \
# 0                       NaN                           NaN
# 1                       NaN                           NaN
# 2                       NaN                           NaN
# 4                       NaN                           NaN
# 6                       NaN                           NaN
#
#    Total Sessions Conducted  Total Individuals Registered  \
# 0                       NaN                           NaN
# 1                       NaN                           NaN
# 2                       NaN                           NaN
# 4                       NaN                           NaN
# 6                       NaN                           NaN
#
#                                         Source  Source 2  Source 3  Source 4  \
# 0           Press_Release_ICMR_13March2020.pdf       NaN       NaN       NaN
# 1      ICMR_website_update_18March_6PM_IST.pdf       NaN       NaN       NaN
# 2  ICMR_website_update_19March_10AM_IST_V2.pdf       NaN       NaN       NaN
# 4     ICMR_website_update_20March_10AM_IST.pdf       NaN       NaN       NaN
# 6     ICMR_website_update_21March_10AM_IST.pdf       NaN       NaN       NaN
#
#    Testing_Date
# 0    2020-03-13
# 1    2020-03-18
# 2    2020-03-19
# 4    2020-03-20
# 6    2020-03-21
#
# [5 rows x 37 columns]

# %%
tests.drop(tests.tail(3).index, inplace = True)
tests.dropna(subset=["Daily RTPCR Samples Collected_ICMR Application"], inplace=True)
tests['Daily_Tests'] = tests['Daily RTPCR Samples Collected_ICMR Application']

# %%
# lets join both by dates
result = pd.merge(cases[['Case_Date', 'Daily Confirmed', 'Daily Recovered']],
                  tests[['Testing_Date', 'Daily_Tests']],
                  left_on='Case_Date',
                  right_on='Testing_Date')
result.tail()
# Out:
#      Case_Date  Daily Confirmed  Daily Recovered Testing_Date  Daily_Tests
# 335 2021-05-03           355769           318910   2021-05-03     584547.0
# 336 2021-05-04           382847           337699   2021-05-04    1065669.0
# 337 2021-05-05           412624           330718   2021-05-05    1037883.0
# 338 2021-05-06           414280           328347   2021-05-06    1014480.0
# 339 2021-05-07           406902           327675   2021-05-07    1001025.0

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

features = ['Daily_Tests']
target = ['Daily Confirmed']

x_train = result[features]
y_train = result[target]

x_train.shape, y_train.shape

model.fit(x_train, y_train)

# tests for next 3 days = 934541, 580038, 1013002
# confirmed for next 3 days = 403808, 366455, 329491

x_test = [[934541], [580038], [1013002]]

y_pred = model.predict(x_test)
y_pred
# Out:
# array([[221985.39353552],
#        [112872.33748296],
#        [246135.03258212]])

# %%
y_test = [403808, 366455, 329491]

from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
print("Mean absolute error of our model", mae)
# Out:
# Mean absolute error of our model 172920.4121331323

# %%
# the second wave has behaved differently due to mutations and new strains
# we will limit the dataframe to after march this year

filteredResults = result[result['Case_Date'] >= '2021-03-01']
filteredResults.shape


from sklearn.linear_model import LinearRegression
model = LinearRegression()

features = ['Daily_Tests']
target = ['Daily Confirmed']

x_train = filteredResults[features]
y_train = filteredResults[target]

x_train.shape, y_train.shape

model.fit(x_train, y_train)

# tests for next 3 days = 934541, 580038, 1013002
# confirmed for next 3 days = 403808, 366455, 329491

x_test = [[1013002]]

y_pred = model.predict(x_test)
y_pred[0][0]
# Out:
# 328187.01576283155

# %%
y_test = [329491]

from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
print("Mean absolute error of our model", mae)
# Out:
# Mean absolute error of our model 1303.98423716845
